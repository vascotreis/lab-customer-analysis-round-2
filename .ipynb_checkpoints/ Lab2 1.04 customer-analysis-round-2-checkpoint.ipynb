# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('files_for_lab/csv_files/marketing_customer_analysis.csv')

# %%
data
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0         Basic   College           2/18/11         Employed      M  ...
# 1         Basic   College           1/18/11       Unemployed      F  ...
# 2         Basic  Bachelor           2/10/11         Employed      M  ...
# 3      Extended   College           1/11/11         Employed      M  ...
# 4       Premium  Bachelor           1/17/11    Medical Leave      F  ...
# ...         ...       ...               ...              ...    ...  ...
# 10905   Premium  Bachelor           1/19/11       Unemployed      F  ...
# 10906     Basic   College            1/6/11         Employed      F  ...
# 10907  Extended  Bachelor            2/6/11         Employed      F  ...
# 10908   Premium   College           2/13/11         Employed      F  ...
# 10909     Basic  Bachelor            1/8/11       Unemployed      M  ...
#
#        Number of Open Complaints Number of Policies     Policy Type  \
# 0                            0.0                  9  Corporate Auto
# 1                            0.0                  1   Personal Auto
# 2                            0.0                  2   Personal Auto
# 3                            0.0                  2  Corporate Auto
# 4                            NaN                  7   Personal Auto
# ...                          ...                ...             ...
# 10905                        NaN                  7   Personal Auto
# 10906                        0.0                  6   Personal Auto
# 10907                        0.0                  2  Corporate Auto
# 10908                        4.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              Policy  Renew Offer Type  Sales Channel  Total Claim Amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        Vehicle Class Vehicle Size Vehicle Type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 26 columns]

# %%
data.shape
# Out:
# (10910, 26)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
data = data.drop(['Unnamed: 0'], axis = 1)

# %%
data
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       Education Effective To Date EmploymentStatus Gender  Income  ...  \
# 0       College           2/18/11         Employed      M   48029  ...
# 1       College           1/18/11       Unemployed      F       0  ...
# 2      Bachelor           2/10/11         Employed      M   22139  ...
# 3       College           1/11/11         Employed      M   49078  ...
# 4      Bachelor           1/17/11    Medical Leave      F   23675  ...
# ...         ...               ...              ...    ...     ...  ...
# 10905  Bachelor           1/19/11       Unemployed      F       0  ...
# 10906   College            1/6/11         Employed      F   61146  ...
# 10907  Bachelor            2/6/11         Employed      F   39837  ...
# 10908   College           2/13/11         Employed      F   64195  ...
# 10909  Bachelor            1/8/11       Unemployed      M       0  ...
#
#       Number of Open Complaints Number of Policies     Policy Type  \
# 0                           0.0                  9  Corporate Auto
# 1                           0.0                  1   Personal Auto
# 2                           0.0                  2   Personal Auto
# 3                           0.0                  2  Corporate Auto
# 4                           NaN                  7   Personal Auto
# ...                         ...                ...             ...
# 10905                       NaN                  7   Personal Auto
# 10906                       0.0                  6   Personal Auto
# 10907                       0.0                  2  Corporate Auto
# 10908                       4.0                  6   Personal Auto
# 10909                       0.0                  3   Personal Auto
#
#              Policy  Renew Offer Type  Sales Channel  Total Claim Amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        Vehicle Class Vehicle Size Vehicle Type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 25 columns]

# %%
data =  data.rename(columns={'EmploymentStatus':'Employment Status'})
data
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       Education Effective To Date Employment Status Gender  Income  ...  \
# 0       College           2/18/11          Employed      M   48029  ...
# 1       College           1/18/11        Unemployed      F       0  ...
# 2      Bachelor           2/10/11          Employed      M   22139  ...
# 3       College           1/11/11          Employed      M   49078  ...
# 4      Bachelor           1/17/11     Medical Leave      F   23675  ...
# ...         ...               ...               ...    ...     ...  ...
# 10905  Bachelor           1/19/11        Unemployed      F       0  ...
# 10906   College            1/6/11          Employed      F   61146  ...
# 10907  Bachelor            2/6/11          Employed      F   39837  ...
# 10908   College           2/13/11          Employed      F   64195  ...
# 10909  Bachelor            1/8/11        Unemployed      M       0  ...
#
#       Number of Open Complaints Number of Policies     Policy Type  \
# 0                           0.0                  9  Corporate Auto
# 1                           0.0                  1   Personal Auto
# 2                           0.0                  2   Personal Auto
# 3                           0.0                  2  Corporate Auto
# 4                           NaN                  7   Personal Auto
# ...                         ...                ...             ...
# 10905                       NaN                  7   Personal Auto
# 10906                       0.0                  6   Personal Auto
# 10907                       0.0                  2  Corporate Auto
# 10908                       4.0                  6   Personal Auto
# 10909                       0.0                  3   Personal Auto
#
#              Policy  Renew Offer Type  Sales Channel  Total Claim Amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        Vehicle Class Vehicle Size Vehicle Type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 25 columns]

# %%
cols = []
for i in data.columns:
    cols.append(i.lower())
data.columns = cols
data
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective to date employment status gender  income  ...  \
# 0       College           2/18/11          Employed      M   48029  ...
# 1       College           1/18/11        Unemployed      F       0  ...
# 2      Bachelor           2/10/11          Employed      M   22139  ...
# 3       College           1/11/11          Employed      M   49078  ...
# 4      Bachelor           1/17/11     Medical Leave      F   23675  ...
# ...         ...               ...               ...    ...     ...  ...
# 10905  Bachelor           1/19/11        Unemployed      F       0  ...
# 10906   College            1/6/11          Employed      F   61146  ...
# 10907  Bachelor            2/6/11          Employed      F   39837  ...
# 10908   College           2/13/11          Employed      F   64195  ...
# 10909  Bachelor            1/8/11        Unemployed      M       0  ...
#
#       number of open complaints number of policies     policy type  \
# 0                           0.0                  9  Corporate Auto
# 1                           0.0                  1   Personal Auto
# 2                           0.0                  2   Personal Auto
# 3                           0.0                  2  Corporate Auto
# 4                           NaN                  7   Personal Auto
# ...                         ...                ...             ...
# 10905                       NaN                  7   Personal Auto
# 10906                       0.0                  6   Personal Auto
# 10907                       0.0                  2  Corporate Auto
# 10908                       4.0                  6   Personal Auto
# 10909                       0.0                  3   Personal Auto
#
#              policy  renew offer type  sales channel  total claim amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        vehicle class vehicle size vehicle type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 25 columns]

# %%
data.dtypes
# Out:
# customer                          object
# state                             object
# customer lifetime value          float64
# response                          object
# coverage                          object
# education                         object
# effective to date                 object
# employment status                 object
# gender                            object
# income                             int64
# location code                     object
# marital status                    object
# monthly premium auto               int64
# months since last claim          float64
# months since policy inception      int64
# number of open complaints        float64
# number of policies                 int64
# policy type                       object
# policy                            object
# renew offer type                  object
# sales channel                     object
# total claim amount               float64
# vehicle class                     object
# vehicle size                      object
# vehicle type                      object
# dtype: object

# %%
display(data.select_dtypes(np.number).columns)
display(len(data.select_dtypes(np.number).columns))
# Out:
# Index(['customer lifetime value', 'income', 'monthly premium auto',
#        'months since last claim', 'months since policy inception',
#        'number of open complaints', 'number of policies',
#        'total claim amount'],
#       dtype='object')
# 8

# %%
display(data.select_dtypes(object).columns)
display(len(data.select_dtypes(object).columns))
# Out:
# Index(['customer', 'state', 'response', 'coverage', 'education',
#        'effective to date', 'employment status', 'gender', 'location code',
#        'marital status', 'policy type', 'policy', 'renew offer type',
#        'sales channel', 'vehicle class', 'vehicle size', 'vehicle type'],
#       dtype='object')
# 17

# %% [markdown]
# ## check for duplicates

# %%
duplicate = data[data.duplicated()]
display(duplicate)
print(len(duplicate))
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 1134   BV86143         NaN             21034.018150      NaN     Basic
# 2799   YS94121         NaN              5645.396665      NaN     Basic
# 2805   BS34332         NaN              5557.934118      NaN     Basic
# 3590   GE63585         NaN              2420.711888      NaN     Basic
# 3877   GU42671     Arizona              6106.941981       No  Extended
# 4581   ID89933      Oregon              7255.577594       No  Extended
# 4992   GS76685  California             10408.968650      Yes     Basic
# 5734   AL78075      Oregon              3810.238281       No   Premium
# 5863   OJ33945      Oregon              8692.636838       No     Basic
# 6068   EP64069         NaN              5138.244998      NaN     Basic
# 6091   ID89933      Oregon              7255.577594       No  Extended
# 6116   RB49468         NaN              7511.660568      NaN     Basic
# 6117   AM79057         NaN              2287.917290      NaN     Basic
# 6315   GF70857         NaN              2933.960426      NaN  Extended
# 6410   NI17718         NaN              2150.178588      NaN     Basic
# 6578   GM16780      Oregon             36057.537020       No  Extended
# 6699   NJ46471      Oregon              8696.710700       No     Basic
# 6743   ID89933         NaN              7255.577594      NaN  Extended
# 6879   NL75739     Arizona              7590.050089       No     Basic
# 7533   BZ44726         NaN             16477.768430      NaN     Basic
# 7764   DY22043      Oregon              5499.447223       No     Basic
# 7786   VK57280         NaN              4727.354548      NaN     Basic
# 7796   PK26805         NaN              2810.957053      NaN     Basic
# 8509   HJ58678      Nevada              5418.152088       No     Basic
# 8531   LH94971      Oregon              7057.888812       No  Extended
# 8680   NB57112      Oregon              8104.503269       No     Basic
# 8827   BZ44726         NaN             16477.768430      NaN     Basic
# 8847   EZ48093         NaN              2710.811423      NaN     Basic
# 8891   VE98553      Oregon              4666.643522       No   Premium
# 8926   NJ72300      Oregon              8009.028202       No     Basic
# 9095   KB18303         NaN              8658.863813      NaN     Basic
# 9313   LD75023      Oregon             26346.085820       No  Extended
# 9432   ZB87718     Arizona              8714.922135      Yes     Basic
# 9943   FP86246         NaN             13211.010920      NaN   Premium
# 10006  IE40701  California              2877.354255       No     Basic
# 10276  VA78645  California              2188.655055       No     Basic
# 10499  VI66513  California              9688.334578       No  Extended
#
#                   education effective to date employment status gender  \
# 1134   High School or Below           2/23/11          Employed      F
# 2799   High School or Below           2/27/11          Employed      M
# 2805   High School or Below           1/30/11          Employed      F
# 3590               Bachelor            2/7/11          Employed      M
# 3877               Bachelor           2/21/11     Medical Leave      F
# 4581                 Doctor            1/9/11          Employed      F
# 4992   High School or Below           2/18/11           Retired      M
# 5734   High School or Below           2/13/11        Unemployed      M
# 5863   High School or Below            1/8/11          Employed      F
# 6068               Bachelor            1/8/11          Employed      F
# 6091                 Doctor            1/9/11          Employed      F
# 6116               Bachelor           1/20/11        Unemployed      F
# 6117               Bachelor           2/18/11          Employed      F
# 6315                College           1/28/11        Unemployed      M
# 6410   High School or Below            2/9/11        Unemployed      F
# 6578                College            2/7/11          Employed      M
# 6699               Bachelor            1/4/11          Employed      F
# 6743                 Doctor            1/9/11          Employed      F
# 6879   High School or Below            1/2/11          Disabled      M
# 7533   High School or Below           2/26/11          Employed      F
# 7764   High School or Below           1/28/11          Employed      F
# 7786               Bachelor            1/3/11        Unemployed      M
# 7796   High School or Below           2/11/11          Employed      M
# 8509                College           2/10/11          Employed      F
# 8531               Bachelor           1/17/11          Employed      M
# 8680               Bachelor           2/22/11        Unemployed      F
# 8827   High School or Below           2/26/11          Employed      F
# 8847               Bachelor            2/9/11          Employed      M
# 8891               Bachelor           2/28/11          Employed      M
# 8926               Bachelor           1/25/11        Unemployed      F
# 9095                College            2/7/11          Employed      M
# 9313   High School or Below           1/20/11          Employed      M
# 9432                College           2/21/11        Unemployed      F
# 9943               Bachelor           1/31/11          Employed      M
# 10006  High School or Below           1/30/11          Employed      M
# 10276               College            1/9/11        Unemployed      M
# 10499  High School or Below            1/3/11          Employed      M
#
#        income  ... number of open complaints number of policies  \
# 1134    26876  ...                       0.0                  2
# 2799    50366  ...                       0.0                  9
# 2805    83576  ...                       0.0                  5
# 3590    31710  ...                       0.0                  1
# 3877    16654  ...                       0.0                  7
# 4581    39786  ...                       NaN                  9
# 4992    20228  ...                       NaN                  2
# 5734        0  ...                       0.0                  1
# 5863    97768  ...                       NaN                  2
# 6068    72264  ...                       0.0                  9
# 6091    39786  ...                       1.0                  9
# 6116        0  ...                       0.0                  2
# 6117    69024  ...                       5.0                  1
# 6315        0  ...                       0.0                  1
# 6410        0  ...                       0.0                  1
# 6578    90330  ...                       NaN                  2
# 6699    56550  ...                       3.0                  2
# 6743    39786  ...                       NaN                  9
# 6879    10375  ...                       NaN                  2
# 7533    49825  ...                       3.0                  2
# 7764    88768  ...                       0.0                  7
# 7786        0  ...                       0.0                  3
# 7796    20371  ...                       1.0                  1
# 8509    57587  ...                       0.0                  7
# 8531    37840  ...                       0.0                  4
# 8680        0  ...                       1.0                  6
# 8827    49825  ...                       3.0                  2
# 8847    31998  ...                       0.0                  1
# 8891    60466  ...                       NaN                  1
# 8926        0  ...                       NaN                  3
# 9095    62464  ...                       0.0                  4
# 9313    48268  ...                       0.0                  2
# 9432        0  ...                       NaN                  4
# 9943    74656  ...                       0.0                  2
# 10006   32807  ...                       0.0                  1
# 10276       0  ...                       1.0                  1
# 10499   20009  ...                       NaN                  2
#
#           policy type        policy  renew offer type  sales channel  \
# 1134    Personal Auto   Personal L2            Offer4    Call Center
# 2799    Personal Auto   Personal L1            Offer1    Call Center
# 2805    Personal Auto   Personal L3            Offer3            Web
# 3590   Corporate Auto  Corporate L3            Offer1    Call Center
# 3877    Personal Auto   Personal L3            Offer1         Branch
# 4581    Personal Auto   Personal L2            Offer1            Web
# 4992   Corporate Auto  Corporate L3            Offer1         Branch
# 5734    Personal Auto   Personal L2            Offer2         Branch
# 5863    Personal Auto   Personal L1            Offer3          Agent
# 6068   Corporate Auto  Corporate L3            Offer3            Web
# 6091    Personal Auto   Personal L2            Offer1            Web
# 6116    Personal Auto   Personal L3            Offer1         Branch
# 6117    Personal Auto   Personal L2            Offer2            Web
# 6315    Personal Auto   Personal L3            Offer2    Call Center
# 6410    Personal Auto   Personal L3            Offer2            Web
# 6578   Corporate Auto  Corporate L3            Offer1    Call Center
# 6699   Corporate Auto  Corporate L1            Offer3          Agent
# 6743    Personal Auto   Personal L2            Offer1            Web
# 6879    Personal Auto   Personal L3            Offer1         Branch
# 7533   Corporate Auto  Corporate L3            Offer3          Agent
# 7764    Personal Auto   Personal L3            Offer3         Branch
# 7786    Personal Auto   Personal L2            Offer2    Call Center
# 7796    Personal Auto   Personal L2            Offer4    Call Center
# 8509    Personal Auto   Personal L2            Offer3          Agent
# 8531   Corporate Auto  Corporate L2            Offer2          Agent
# 8680    Personal Auto   Personal L2            Offer2          Agent
# 8827   Corporate Auto  Corporate L3            Offer3          Agent
# 8847   Corporate Auto  Corporate L3            Offer3         Branch
# 8891    Personal Auto   Personal L3            Offer2          Agent
# 8926    Personal Auto   Personal L3            Offer2            Web
# 9095   Corporate Auto  Corporate L1            Offer2          Agent
# 9313    Personal Auto   Personal L2            Offer1            Web
# 9432    Personal Auto   Personal L1            Offer1          Agent
# 9943    Personal Auto   Personal L2            Offer3    Call Center
# 10006   Personal Auto   Personal L2            Offer2    Call Center
# 10276   Personal Auto   Personal L3            Offer3         Branch
# 10499  Corporate Auto  Corporate L3            Offer2         Branch
#
#        total claim amount  vehicle class vehicle size vehicle type
# 1134           219.209762  Four-Door Car      Medsize            A
# 2799           428.734656  Four-Door Car        Small            A
# 2805           331.200000   Two-Door Car      Medsize            A
# 3590           199.551735   Two-Door Car      Medsize          NaN
# 3877           379.200000            NaN          NaN            A
# 4581           365.835977            NaN          NaN          NaN
# 4992           523.815839            SUV      Medsize          NaN
# 5734           777.600000            NaN          NaN          NaN
# 5863           151.843731   Two-Door Car      Medsize            A
# 6068           272.649844  Four-Door Car      Medsize          NaN
# 6091           365.835977            NaN          NaN            A
# 6116           340.201412  Four-Door Car      Medsize          NaN
# 6117           238.530745  Four-Door Car      Medsize            A
# 6315           199.851201  Four-Door Car      Medsize            A
# 6410           292.800000  Four-Door Car      Medsize          NaN
# 6578           192.085299     Sports Car      Medsize            A
# 6699           162.775889            NaN          NaN            A
# 6743           365.835977            NaN          NaN          NaN
# 6879           316.800000   Two-Door Car      Medsize            A
# 7533           336.000000   Two-Door Car      Medsize          NaN
# 7764           326.400000            NaN          NaN          NaN
# 7786           345.600000  Four-Door Car      Medsize          NaN
# 7796           340.800000  Four-Door Car      Medsize          NaN
# 8509           257.090387            NaN          NaN          NaN
# 8531           432.000000            NaN          NaN            A
# 8680           842.400000            NaN          NaN            A
# 8827           336.000000   Two-Door Car      Medsize          NaN
# 8847           331.200000  Four-Door Car        Small            A
# 8891           784.186389  Four-Door Car        Large            A
# 8926           740.963933            SUV        Small            A
# 9095           400.181882     Sports Car      Medsize          NaN
# 9313          1605.600000            NaN          NaN            A
# 9432           566.400000            SUV      Medsize          NaN
# 9943           504.365927            NaN          NaN            A
# 10006          350.400000            NaN          NaN            A
# 10276          321.600000            NaN          NaN          NaN
# 10499          987.122788  Four-Door Car        Small            A
#
# [37 rows x 25 columns]
# 37

# %% [markdown]
# ## drop duplicates

# %%
data = data.drop_duplicates()

# %%
duplicate = data[data.duplicated()]
display(duplicate)
print(len(duplicate))
# Out:
# Empty DataFrame
# Columns: [customer, state, customer lifetime value, response, coverage, education, effective to date, employment status, gender, income, location code, marital status, monthly premium auto, months since last claim, months since policy inception, number of open complaints, number of policies, policy type, policy, renew offer type, sales channel, total claim amount, vehicle class, vehicle size, vehicle type]
# Index: []
#
# [0 rows x 25 columns]
# 0

# %%
round(data.isna().sum()/len(data),4)*100  # shows the percentage of null values in a column
nulls_df = pd.DataFrame(round(data.isna().sum()/len(data),4)*100)
nulls_df = nulls_df.reset_index()
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#                       header_name  percent_nulls
# 0                        customer           0.00
# 1                           state           5.65
# 2         customer lifetime value           0.00
# 3                        response           5.65
# 4                        coverage           0.00
# 5                       education           0.00
# 6               effective to date           0.00
# 7               employment status           0.00
# 8                          gender           0.00
# 9                          income           0.00
# 10                  location code           0.00
# 11                 marital status           0.00
# 12           monthly premium auto           0.00
# 13        months since last claim           5.73
# 14  months since policy inception           0.00
# 15      number of open complaints           5.73
# 16             number of policies           0.00
# 17                    policy type           0.00
# 18                         policy           0.00
# 19               renew offer type           0.00
# 20                  sales channel           0.00
# 21             total claim amount           0.00
# 22                  vehicle class           5.59
# 23                   vehicle size           5.59
# 24                   vehicle type          50.26

# %%
data["vehicle type"].value_counts(dropna=False)
# Out:
# NaN    5465
# A      5408
# Name: vehicle type, dtype: int64

# %%
data["state"].value_counts(dropna=False)
# Out:
# California    3548
# Oregon        2897
# Arizona       1934
# Nevada         992
# Washington     888
# NaN            614
# Name: state, dtype: int64

# %% [markdown]
# ### deleting NaN rows is state (and responce bcs they´r in the same rows )

# %%
data = data.drop(labels = data[data['response'].isnull()].index.tolist(), axis = 0)

# %%
data.isna().sum()
# Out:
# customer                            0
# state                               0
# customer lifetime value             0
# response                            0
# coverage                            0
# education                           0
# effective to date                   0
# employment status                   0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           582
# months since policy inception       0
# number of open complaints         582
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     579
# vehicle size                      579
# vehicle type                     5157
# dtype: int64

# %% [markdown]
# ### checking rows

# %%
na_claim = data[data['months since last claim'].isnull()].index.tolist()
na_complaints = data[data['number of open complaints'].isnull()].index.tolist()
for i in range(582):
    if na_claim[i] == na_complaints[i]:
        print(True)
    else:
        print(False)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
data["months since last claim"].value_counts(dropna=False)
# Out:
# NaN     582
# 3.0     401
# 6.0     381
# 1.0     364
# 7.0     354
# 4.0     353
# 2.0     348
# 5.0     331
# 0.0     329
# 10.0    323
# 16.0    318
# 11.0    316
# 15.0    303
# 8.0     297
# 13.0    295
# 12.0    289
# 17.0    283
# 14.0    280
# 19.0    263
# 9.0     263
# 23.0    261
# 25.0    253
# 21.0    250
# 20.0    246
# 18.0    244
# 22.0    231
# 29.0    222
# 24.0    221
# 28.0    209
# 26.0    202
# 31.0    201
# 27.0    193
# 30.0    192
# 33.0    188
# 34.0    185
# 35.0    148
# 32.0    140
# Name: months since last claim, dtype: int64

# %%
data = data.drop(labels = data[data['response'].isnull()].index.tolist(), axis = 0)

# %%
data = data[data['months since last claim'].isna()==False] 
print(data.isna().sum())
data.shape
# Out:
# customer                            0
# state                               0
# customer lifetime value             0
# response                            0
# coverage                            0
# education                           0
# effective to date                   0
# employment status                   0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim             0
# months since policy inception       0
# number of open complaints           0
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     543
# vehicle size                      543
# vehicle type                     4861
# dtype: int64
# (9677, 25)

# %%
data = data[data['vehicle class'].isna()==False] 
print(data.isna().sum())
data.shape
# Out:
# customer                            0
# state                               0
# customer lifetime value             0
# response                            0
# coverage                            0
# education                           0
# effective to date                   0
# employment status                   0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim             0
# months since policy inception       0
# number of open complaints           0
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                       0
# vehicle size                        0
# vehicle type                     4591
# dtype: int64
# (9134, 25)

# %%
data['month'] = pd.DatetimeIndex(data['effective to date']).month

# %%
data[data.month.isin([1,2,3])].sort_index(ascending=True).sample(5)
# Out:
#      customer       state  customer lifetime value response  coverage  \
# 5635  PD69398  Washington             21710.275380       No  Extended
# 955   XB35510  California              8704.278179       No     Basic
# 8013  ZG69918      Oregon              8168.714346       No     Basic
# 5356  PU75847     Arizona              4964.666365       No     Basic
# 2481  ST59524      Oregon              2657.570431       No     Basic
#
#      education effective to date employment status gender  income  ...  \
# 5635   College           2/26/11          Employed      M   62370  ...
# 955   Bachelor            1/5/11          Employed      M   38072  ...
# 8013   College           1/14/11          Disabled      M   20819  ...
# 5356   College           1/31/11          Employed      M   98451  ...
# 2481   College           1/13/11        Unemployed      M       0  ...
#
#      number of policies     policy type        policy  renew offer type  \
# 5635                  2  Corporate Auto  Corporate L1            Offer2
# 955                   3   Personal Auto   Personal L3            Offer1
# 8013                  2    Special Auto    Special L2            Offer1
# 5356                  3   Personal Auto   Personal L3            Offer4
# 2481                  1   Personal Auto   Personal L1            Offer3
#
#       sales channel  total claim amount  vehicle class vehicle size  \
# 5635    Call Center           32.007610  Four-Door Car      Medsize
# 955          Branch          151.055863            SUV      Medsize
# 8013    Call Center          206.863422  Four-Door Car      Medsize
# 5356          Agent          316.546868  Four-Door Car        Small
# 2481    Call Center          340.800000  Four-Door Car      Medsize
#
#      vehicle type month
# 5635          NaN     2
# 955             A     1
# 8013          NaN     1
# 5356          NaN     1
# 2481          NaN     1
#
# [5 rows x 26 columns]

# %%
data['month'].unique()
# Out:
# array([2, 1])

# %%
data
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   education effective to date employment status gender  \
# 0                   College           2/18/11          Employed      M
# 1                   College           1/18/11        Unemployed      F
# 2                  Bachelor           2/10/11          Employed      M
# 3                   College           1/11/11          Employed      M
# 6                    Doctor           2/14/11          Employed      F
# ...                     ...               ...               ...    ...
# 10903               College            1/7/11          Employed      M
# 10904  High School or Below           2/24/11        Unemployed      M
# 10906               College            1/6/11          Employed      F
# 10907              Bachelor            2/6/11          Employed      F
# 10908               College           2/13/11          Employed      F
#
#        income  ... number of policies     policy type        policy  \
# 0       48029  ...                  9  Corporate Auto  Corporate L3
# 1           0  ...                  1   Personal Auto   Personal L3
# 2       22139  ...                  2   Personal Auto   Personal L3
# 3       49078  ...                  2  Corporate Auto  Corporate L3
# 6       37405  ...                  4  Corporate Auto  Corporate L2
# ...       ...  ...                ...             ...           ...
# 10903   59855  ...                  1   Personal Auto   Personal L2
# 10904       0  ...                  2   Personal Auto   Personal L2
# 10906   61146  ...                  6   Personal Auto   Personal L3
# 10907   39837  ...                  2  Corporate Auto  Corporate L3
# 10908   64195  ...                  6   Personal Auto   Personal L1
#
#        renew offer type  sales channel  total claim amount  vehicle class  \
# 0                Offer3          Agent          292.800000  Four-Door Car
# 1                Offer4    Call Center          744.924331  Four-Door Car
# 2                Offer3    Call Center          480.000000            SUV
# 3                Offer2         Branch          484.013411  Four-Door Car
# 6                Offer2         Branch          287.556107  Four-Door Car
# ...                 ...            ...                 ...            ...
# 10903            Offer2         Branch          355.200000   Two-Door Car
# 10904            Offer1         Branch          897.600000     Luxury SUV
# 10906            Offer2         Branch          273.018929  Four-Door Car
# 10907            Offer1            Web          381.306996     Luxury SUV
# 10908            Offer1         Branch          618.288849            SUV
#
#       vehicle size vehicle type month
# 0          Medsize          NaN     2
# 1          Medsize          NaN     1
# 2          Medsize            A     2
# 3          Medsize            A     1
# 6          Medsize          NaN     2
# ...            ...          ...   ...
# 10903      Medsize            A     1
# 10904      Medsize            A     2
# 10906      Medsize            A     1
# 10907      Medsize          NaN     2
# 10908      Medsize            A     2
#
# [9134 rows x 26 columns]

# %% [markdown]
# # Round 3

# %%
#data fraeme info

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9134 entries, 0 to 10908
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9134 non-null   object
#  1   state                          9134 non-null   object
#  2   customer lifetime value        9134 non-null   float64
#  3   response                       9134 non-null   object
#  4   coverage                       9134 non-null   object
#  5   education                      9134 non-null   object
#  6   effective to date              9134 non-null   object
#  7   employment status              9134 non-null   object
#  8   gender                         9134 non-null   object
#  9   income                         9134 non-null   int64
#  10  location code                  9134 non-null   object
#  11  marital status                 9134 non-null   object
#  12  monthly premium auto           9134 non-null   int64
#  13  months since last claim        9134 non-null   float64
#  14  months since policy inception  9134 non-null   int64
#  15  number of open complaints      9134 non-null   float64
#  16  number of policies             9134 non-null   int64
#  17  policy type                    9134 non-null   object
#  18  policy                         9134 non-null   object
#  19  renew offer type               9134 non-null   object
#  20  sales channel                  9134 non-null   object
#  21  total claim amount             9134 non-null   float64
#  22  vehicle class                  9134 non-null   object
#  23  vehicle size                   9134 non-null   object
#  24  vehicle type                   4543 non-null   object
#  25  month                          9134 non-null   int64
# dtypes: float64(4), int64(5), object(17)
# memory usage: 1.9+ MB

# %%
#describe data
data.describe()
# Out:
#        customer lifetime value        income  monthly premium auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        months since last claim  months since policy inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# 25%                   6.000000                      24.000000
# 50%                  14.000000                      48.000000
# 75%                  23.000000                      71.000000
# max                  35.000000                      99.000000
#
#        number of open complaints  number of policies  total claim amount  \
# count                9134.000000         9134.000000         9134.000000
# mean                    0.384388            2.966170          434.088794
# std                     0.910384            2.390182          290.500092
# min                     0.000000            1.000000            0.099007
# 25%                     0.000000            1.000000          272.258244
# 50%                     0.000000            2.000000          383.945434
# 75%                     0.000000            4.000000          547.514839
# max                     5.000000            9.000000         2893.239678
#
#              month
# count  9134.000000
# mean      1.463762
# std       0.498712
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.000000
# max       2.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
data['response'].value_counts()
# Out:
# No     7826
# Yes    1308
# Name: response, dtype: int64

# %%
data['response_numerical'] = data['response'].map(dict(Yes=1, No=0))

# %%
sns.countplot(x=data['response'])
# Out:
# <AxesSubplot:xlabel='response', ylabel='count'>

# %%
sns.barplot(x='response_numerical',y='sales channel', data=data)
plt.show()

# %%
sns.barplot(x='response_numerical',y='total claim amount', data=data)
plt.show()

# %%
sns.barplot(x = data["response_numerical"], y = data['total claim amount'])
plt.show()

# %%
sns.displot(x =data['total claim amount'], y = data["response_numerical"], bins=10)

# %%
data['claims'] = pd.qcut(data['total claim amount']), q=5)
# Out:
#   File "/var/folders/vp/2wvfyb695rg5q5v9fgk55vpr0000gn/T/ipykernel_28400/1534808195.py", line 1
#     data['claims'] = pd.qcut(data['total claim amount']), q=5)
#                      ^
# SyntaxError: cannot assign to function call

# %%
data["claims"].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'claims'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/vp/2wvfyb695rg5q5v9fgk55vpr0000gn/T/ipykernel_28400/2697909407.py in <module>
# ----> 1 data["claims"].unique()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'claims'
